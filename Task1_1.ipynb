# %% [markdown]
# Task1.1. Install Jupyter notebook and run the first program and share the screenshot of the output.
#
# Ans:
# Dear Team, I am using CentOS 7 linux operationg system. For Installing Jupyter notebook, First I installed Anaconda Python in my system. For this, I downloaded linux downloadable using the below link.
# https://repo.anaconda.com/archive/Anaconda3-2020.02-Linux-x86_64.sh
#
# Then I installed it using bash. Provided the path where to install anaconda python and source it into .bashrc file.
#
# Now  open terminal, and type jupyter notebook and after then entered the enter key from keyboard. Then it opened jupyter notebook in my default browser (in google chrome).

# %%
# run the first program
print("Thanks Ineuron team for providing the wonderful course")
print("This is Malleswararao working as a Manager regarding Wind power and Solar power intra day and dayahead forecasting")
print("I am a meteorologist and experience in numerical weather modelling")
# Out:
# Thanks Ineuron team for providing the wonderful course
# This is Malleswararao working as a Manager regarding Wind power and Solar power intra day and dayahead forecasting
# I am a meteorologist and experience in numerical weather modelling

# %% [markdown]
# ![screenshot.png](attachment:screenshot.png)
